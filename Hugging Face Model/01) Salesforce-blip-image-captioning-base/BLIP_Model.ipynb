# %% [markdown]
# **BLIP (Bootstrapping Language-Image Pre-training)**
#
# * This model generates image captions. You can start by testing this model for its accuracy and speed in generating descriptions.
#
# * Hugging Face model: Salesforce/blip-image-captioning-base

# %%
# Impoertant Libraries
# !pip install tensorflow
# !pip install torch torchvision
# !pip install transformers
# !pip install opencv-python
# !pip install SpeechRecognition
# !pip install gTTS
# !pip install pillow
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 94.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 76.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 38.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 9.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 44.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
# ...

# %%
from transformers import BlipProcessor, BlipForConditionalGeneration
from PIL import Image
import requests

processor = BlipProcessor.from_pretrained("Salesforce/blip-image-captioning-base")
model = BlipForConditionalGeneration.from_pretrained("Salesforce/blip-image-captioning-base")

def generate_caption(image_path):
    img = Image.open(image_path)
    inputs = processor(images=img, return_tensors="pt")
    out = model.generate(**inputs)
    return processor.decode(out[0], skip_special_tokens=True)

# %% [markdown]
# Example usage

# %%
print("1)",generate_caption('/content/1.jpg'))
print("2)",generate_caption('/content/2.jpeg'))
print("3)",generate_caption('/content/3.jpg'))
print("4)",generate_caption('/content/4.jpg'))
print("5)",generate_caption('/content/5.jpg'))
print("6)",generate_caption('/content/6.jpg'))
print("7)",generate_caption('/content/7.jpg'))
print("8)",generate_caption('/content/8.jpg'))
print("9)",generate_caption('/content/9.jpg'))
print("10)",generate_caption('/content/10.jpg'))
print("11)",generate_caption('/content/11.jpg'))
print("12)",generate_caption('/content/12.jpg'))
print("13)",generate_caption('/content/13.jpg'))
print("14)",generate_caption('/content/14.jpg'))
print("15)",generate_caption('/content/15.jpg'))
print("16)",generate_caption('/content/16.jpg'))
print("17)",generate_caption('/content/17.jpg'))
print("18)",generate_caption('/content/18.jpg'))
print("19)",generate_caption('/content/19.jpg'))
print("20)",generate_caption('/content/20.jpg'))
print("21)",generate_caption('/content/21.jpg'))
print("22)",generate_caption('/content/22.jpg'))
print("23)",generate_caption('/content/23.jpg'))
print("24)",generate_caption('/content/24.jpg'))
print("25)",generate_caption('/content/25.jpg'))
print("26)",generate_caption('/content/26.jpg'))
print("27)",generate_caption('/content/27.jpg'))
print("28)",generate_caption('/content/28.jpg'))
print("29)",generate_caption('/content/29.jpg'))
print("30)",generate_caption('/content/30.jpg'))
# Out:
# 1) a woman taking a photo with a camera
# 2) a woman taking a photo with her camera
# 3) a dog with its tongue out and its mouth open
# 4) a dog running along a lake
# 5) a black and white photo of a pug
# 6) a black and white dog with its tongue out
# 7) a woman holding a dog in a forest
# 8) a cat wearing a red bow tie sitting on a white table
# 9) a cat sitting on a window sie
# 10) a group of kittens playing in the grass
# 11) a tiger walking on a log in the grass
# 12) a sheep is laying in the grass in a field
# 13) a person standing in front of a mountain
# 14) a group of cows walking down a dirt road
# 15) a cable car is going up a mountain
# 16) a group of people walking up a hill
# 17) a lake with rocks and a mountain in the background
# 18) three pairs of glasses on a white surface
# 19) a security camera on a wall
# 20) a long exposure of a lighthouse on a rocky beach
# 21) a boat on the water
# 22) a dock on a lake with a blue sky
# ...
