# %% [markdown]
# **ViT-GPT2 (Vision Transformer + GPT2)**
#
# * This combines ViT (for image feature extraction) and GPT-2 (for natural language generation).
#
# * Hugging Face model: nlpconnect/vit-gpt2-image-captioning

# %%
# Impoertant Libraries
# !pip install tensorflow
# !pip install torch torchvision
# !pip install transformers
# !pip install opencv-python
# !pip install SpeechRecognition
# !pip install gTTS
# !pip install pillow

# %%
from transformers import VisionEncoderDecoderModel, ViTFeatureExtractor, AutoTokenizer
from PIL import Image

model = VisionEncoderDecoderModel.from_pretrained("nlpconnect/vit-gpt2-image-captioning")
feature_extractor = ViTFeatureExtractor.from_pretrained("nlpconnect/vit-gpt2-image-captioning")
tokenizer = AutoTokenizer.from_pretrained("nlpconnect/vit-gpt2-image-captioning")

def vit_gpt2_caption(image_path):
    img = Image.open(image_path)
    pixel_values = feature_extractor(images=img, return_tensors="pt").pixel_values
    out = model.generate(pixel_values)
    return tokenizer.decode(out[0], skip_special_tokens=True)

# %% [markdown]
# Example usage

# %%
print("1)",vit_gpt2_caption('/content/1.jpg'))
print("2)",vit_gpt2_caption('/content/2.jpeg'))
print("3)",vit_gpt2_caption('/content/3.jpg'))
print("4)",vit_gpt2_caption('/content/4.jpg'))
print("5)",vit_gpt2_caption('/content/5.jpg'))
print("6)",vit_gpt2_caption('/content/6.jpg'))
print("7)",vit_gpt2_caption('/content/7.jpg'))
print("8)",vit_gpt2_caption('/content/8.jpg'))
print("9)",vit_gpt2_caption('/content/9.jpg'))
print("10)",vit_gpt2_caption('/content/10.jpg'))
print("11)",vit_gpt2_caption('/content/11.jpg'))
print("12)",vit_gpt2_caption('/content/12.jpg'))
print("13)",vit_gpt2_caption('/content/13.jpg'))
print("14)",vit_gpt2_caption('/content/14.jpg'))
print("15)",vit_gpt2_caption('/content/15.jpg'))
print("16)",vit_gpt2_caption('/content/16.jpg'))
print("17)",vit_gpt2_caption('/content/17.jpg'))
print("18)",vit_gpt2_caption('/content/18.jpg'))
print("19)",vit_gpt2_caption('/content/19.jpg'))
print("20)",vit_gpt2_caption('/content/20.jpg'))
print("21)",vit_gpt2_caption('/content/21.jpg'))
print("22)",vit_gpt2_caption('/content/22.jpg'))
print("23)",vit_gpt2_caption('/content/23.jpg'))
print("24)",vit_gpt2_caption('/content/24.jpg'))
print("25)",vit_gpt2_caption('/content/25.jpg'))
print("26)",vit_gpt2_caption('/content/26.jpg'))
print("27)",vit_gpt2_caption('/content/27.jpg'))
print("28)",vit_gpt2_caption('/content/28.jpg'))
print("29)",vit_gpt2_caption('/content/29.jpg'))
print("30)",vit_gpt2_caption('/content/30.jpg'))
# Out:
# 1) a woman taking a picture of herself in the mirror
# 2) a woman in a hat holding a camera
# 3) a dog chewing on a frisbee in the woods
# 4) a dog is standing on a ledge near a river
# 5) a dog with a black collar and a black eye
# 6) a black and white dog with a black and white dog
# 7) a woman walking with a dog in the woods
# 8) a cat wearing a bow tie on a table
# 9) a cat sitting on a window sill looking out
# 10) a pair of kittens are playing with each other
# 11) a brown and white striped cat sitting on a wooden bench
# 12) sheep grazing on a grassy hillside
# 13) a man standing on top of a hill with a camera
# 14) a herd of cattle walking down a dirt road
# 15) a large white and black airplane flying over a hill
# 16) people are walking down a hill with their backpacks
# 17) a lake with a mountain range and mountains
# 18) a collection of scissors and other objects
# 19) a street light with a person standing on it
# 20) a lighthouse with a white and red sailboat
# ...
